# %% [markdown]
# # Azure AutoML for Images
#
# ## AutoML for Images to train and a deploy a flower image classification model (Part 2)
#
# Important: This feature is currently in public preview. This preview version is provided without a service-level agreement. Certain features might not be supported or might have constrained capabilities. For more information, see Supplemental Terms of Use for Microsoft Azure Previews.
#
# Serge Retkowsky | serge.retkowsky@microsoft.com | V1 15-June-2022

# %% [markdown]
# ### Agenda:
# In this notebook you will:
# - Connect to the deployed Azure AutoML for Images CV model we made in the previous notebook
# - Do some test using differents images of flowers to predict its class

# %%
import azureml.core
from azureml.core import Workspace, Dataset
from azureml.core.webservice import Webservice
import requests
import json
import matplotlib.pyplot as plt
import time
from IPython.display import Image
import datetime
import numpy as np
import cv2

# %%
ws = Workspace.from_config()
print("Azure ML workspace:", ws.name, "\nAzure ML resource group:", ws.resource_group)
# Out:
# Azure ML workspace: azuremlvision
# Azure ML resource group: azuremlvision-rg

# %%
print(datetime.datetime.today())
# Out:
# 2022-06-15 15:55:15.603641

# %%
import sys
sys.version
# Out:
# '3.8.5 (default, Sep  4 2020, 07:30:14) \n[GCC 7.3.0]'

# %% [markdown]
# ## AutoML for Images deployed model

# %%
service = Webservice(workspace = ws, name = 'flowers-classification-model')
#print(service.scoring_uri)
#print(service.swagger_uri)

# %%
primary, secondary = service.get_keys()

# %%
# URL for the web service
scoring_uri = service.scoring_uri
# If the service is authenticated, set the key or token
key = primary

# %% [markdown]
# ## Function to call the deployed model

# %%
def flowers_model(test_image):
    
    t1 = time.time()
    
    print("\n\033[1;31;34mPredicting the image ...\n")
    print("Image file:", test_image, "\n")
    
    input_image = open(test_image, 'rb').read()
    headers = {'Content-Type': 'application/json'}
    headers['Authorization'] = f'Bearer {key}'
    resp = requests.post(scoring_uri, input_image, headers = headers)
    detections = json.loads(resp.text)
    print(detections)
    
    label_index = np.argmax(detections['probs'])
    label = detections['labels'][label_index]
    conf_score = detections['probs'][label_index]
    
    print("\n>> This flower is from the\033[1;31;91m", str.upper(label), 
          "\033[1;31;34mfamily with a confidence =", round(conf_score * 100, 2), "%")
    
    print("\033[0m")
    print("-" * 36)
    print("Response status code:", resp.status_code)
    print("Elapsed:", resp.elapsed)
    print("Full process done in", round(time.time() - t1, 6), "second")
    
    return label, conf_score

# %%
def labelled_image(image_file):
    
    # %matplotlib inline
    img = cv2.imread(image_file)
    resized = cv2.resize(img, (640, 480))
    
    msg1 = label + " (" + str(round(conf_score, 4)) + ")"
    result = cv2.putText(resized, msg1, (20, 50), cv2.FONT_HERSHEY_SIMPLEX, 1, (0, 255, 0), 2, cv2.LINE_AA)
    
    msg2 = "Powered with Azure ML"
    cv2.putText(result, msg2, (350, 450), cv2.FONT_HERSHEY_SIMPLEX, 0.7, (255, 255, 0), 2, cv2.LINE_AA)
    
    plt.figure(figsize = (15, 8))
    plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
    
    output_file =  TEST_DIR + '/predicted_' + os.path.basename(test_image)
    cv2.imwrite(output_file, result)
    print("Image saved in:", output_file)

# %% [markdown]
# ## Testing the model

# %%
IMAGES_DIR = 'flowers-images'
TEST_DIR = IMAGES_DIR + '/test'

# %%
test_image = TEST_DIR + '/test (1).jpg'

from IPython.display import Image
Image(filename = test_image, width = 640, height = 480)

# %%
label, conf_score = flowers_model(test_image)
# Out:
# Predicting the image ...
#
# Image file: flowers-images/test/test (1).jpg
#
# {'filename': '/tmp/tmplpnhb6sr/tmps8outgmd', 'probs': [0.000738634611479938, 0.0002039473329205066, 0.9947851300239563, 0.002774028806015849, 0.0014982520369812846], 'labels': ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']}
#
# >> This flower is from the ROSES family with a confidence = 99.48 %
#
# ------------------------------------
# Response status code: 200
# Elapsed: 0:00:00.198963
# Full process done in 0.244167 second

# %%
label, conf_score
# Out:
# ('roses', 0.9947851300239563)

# %%
labelled_image(test_image)
# Out:
# Image saved in: flowers-images/test/predicted_test (1).jpg

# %%
test_image = TEST_DIR + '/test (2).jpg'

from IPython.display import Image
Image(filename = test_image, width = 640, height = 480)

# %%
label, conf_score = flowers_model(test_image)
# Out:
# Predicting the image ...
#
# Image file: flowers-images/test/test (2).jpg
#
# {'filename': '/tmp/tmp21q7b_xm/tmpbacj8nrh', 'probs': [8.0331796198152e-05, 0.00015549735690001398, 0.0007644911529496312, 8.338713814737275e-05, 0.9989162683486938], 'labels': ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']}
#
# >> This flower is from the TULIPS family with a confidence = 99.89 %
#
# ------------------------------------
# Response status code: 200
# Elapsed: 0:00:00.158632
# Full process done in 0.215101 second

# %%
label, conf_score
# Out:
# ('tulips', 0.9989162683486938)

# %%
labelled_image(test_image)
# Out:
# Image saved in: flowers-images/test/predicted_test (2).jpg

# %%
test_image = TEST_DIR + '/test (3).jpg'

from IPython.display import Image
Image(filename = test_image, width = 640, height = 480)

# %%
label, conf_score = flowers_model(test_image)
# Out:
# Predicting the image ...
#
# Image file: flowers-images/test/test (3).jpg
#
# {'filename': '/tmp/tmpk1x610ah/tmpi2fyth5l', 'probs': [0.9968870282173157, 0.0018201909260824323, 0.00026858277851715684, 0.0009158035391010344, 0.00010832710540853441], 'labels': ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']}
#
# >> This flower is from the DAISY family with a confidence = 99.69 %
#
# ------------------------------------
# Response status code: 200
# Elapsed: 0:00:00.137267
# Full process done in 0.165417 second

# %%
label, conf_score
# Out:
# ('daisy', 0.9968870282173157)

# %%
labelled_image(test_image)
# Out:
# Image saved in: flowers-images/test/predicted_test (3).jpg

# %% [markdown]
# ## We can download an image from the web

# %%
url = "https://images.freeimages.com/images/large-previews/f1b/tulipe-01-1496573.jpg"

print("Downloading image from:", url)
urlfile = requests.get(url, allow_redirects = True)
savedimage = 'flowers-images/test/download.jpg'
open(savedimage, 'wb').write(urlfile.content)

from IPython.display import Image
Image(filename = savedimage, width = 640, height = 480)
# Out:
# Downloading image from: https://images.freeimages.com/images/large-previews/f1b/tulipe-01-1496573.jpg

# %%
label, conf_score = flowers_model(savedimage)
# Out:
# Predicting the image ...
#
# Image file: flowers-images/test/download.jpg
#
# {'filename': '/tmp/tmpjy3_akq8/tmp09mysp79', 'probs': [8.902637637220323e-05, 7.825256034266204e-05, 0.001052464242093265, 0.00012178412725916132, 0.9986584186553955], 'labels': ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']}
#
# >> This flower is from the TULIPS family with a confidence = 99.87 %
#
# ------------------------------------
# Response status code: 200
# Elapsed: 0:00:00.181463
# Full process done in 0.214348 second

# %%
label, conf_score
# Out:
# ('tulips', 0.9986584186553955)

# %%
labelled_image(savedimage)
# Out:
# Image saved in: flowers-images/test/predicted_test (3).jpg

# %%
url = "https://robinasbell.com/wp-content/uploads/2012/03/sunflower.jpg"

print("Downloading image from:", url)
urlfile = requests.get(url, allow_redirects = True)
savedimage = 'flowers-images/test/download.jpg'
open(savedimage, 'wb').write(urlfile.content)

from IPython.display import Image
Image(filename = savedimage, width = 640, height = 480)
# Out:
# Downloading image from: https://robinasbell.com/wp-content/uploads/2012/03/sunflower.jpg

# %%
label, conf_score = flowers_model(savedimage)
# Out:
# Predicting the image ...
#
# Image file: flowers-images/test/download.jpg
#
# {'filename': '/tmp/tmpina20nqe/tmp65o450vj', 'probs': [0.0005078230169601738, 0.0003318895760457963, 0.00013586496061179787, 0.9988453388214111, 0.0001790466340025887], 'labels': ['daisy', 'dandelion', 'roses', 'sunflowers', 'tulips']}
#
# >> This flower is from the SUNFLOWERS family with a confidence = 99.88 %
#
# ------------------------------------
# Response status code: 200
# Elapsed: 0:00:00.276583
# Full process done in 0.317407 second

# %%
label, conf_score
# Out:
# ('sunflowers', 0.9988453388214111)

# %%
labelled_image(savedimage)
# Out:
# Image saved in: flowers-images/test/predicted_test (3).jpg
